# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import os

# %%
os.chdir("C:/Users/Dell-/Desktop/AUC/DIH/Git/EagleEye") # Change working directory to project (hacky way to avoid path issues)

# %%
#Lets start with the analysis of the dim data
# #1 dim_add_ons

dim_add_ons = pd.read_csv("Data\\dim_add_ons.csv")
dim_add_ons.head()
# Out:
#       id  user_id     created     updated  category_id  deleted  demo_mode  \
# 0  59840      423  1610874595  1719406250        81504        0          0
# 1  59841      423  1610874595  1719406250        81504        0          0
# 2  59844      423  1610875148  1719406250        81504        0          0
# 3  59845      423  1610875148  1719406250        81504        0          0
# 4  59848      423  1610875674  1719406250        81504        0          0
#
#    index  price  select_as_default  status            title
# 0      0    0.0                  0  Active   The Rudimental
# 1      0    0.0                  0  Active      The Classic
# 2      0    0.0                  0  Active   The Rudimental
# 3      0    0.0                  0  Active       The Garden
# 4      0    0.0                  0  Active  Real Chili Mayo

# %%
# #2 skipped since itso only 2 rows

# %%
# #3 dim_campaigns
dim_campaigns = pd.read_csv("Data\\dim_campaigns.csv")
dim_campaigns.head()
# Out:
#       id  user_id     created     updated  place_id    status  \
# 0  60594      423  1612819150  1659482246     59897  Inactive
# 1  60609      423  1612819657  1659482250     59897  Inactive
# 2  60610      423  1612820393  1659482250     59821  Inactive
# 3  60611      423  1612820493  1659482250     59821  Inactive
# 4  61343      423  1614261570  1659482279     59821  Inactive
#
#                               type
# 0  Discount on specific menu items
# 1  Discount on specific menu items
# 2   2 for 1 on specific menu items
# 3  Discount on specific menu items
# 4           Discount on total bill

# %%
# #4 dim_items
dim_items = pd.read_csv("Data\\dim_items.csv")
dim_items.head()
# Out:
# C:\Users\Dell-\AppData\Local\Temp\ipykernel_27188\2365910716.py:2: DtypeWarning: Columns (0: printer_category_ids, 1: all_you_can_eat_item_ids) have mixed types. Specify dtype option on import or set low_memory=False.
#   dim_items = pd.read_csv("Data\\dim_items.csv")
#       id  user_id     created     updated  accounting_reference barcode  \
# 0  59837      423  1610874221  1719416473                   NaN     NaN
# 1  59838      423  1610874348  1719416473                   NaN     NaN
# 2  59839      423  1610874458  1719416473                   NaN     NaN
# 3  59843      423  1610875050  1741152796                   NaN     NaN
# 4  59856      423  1610875873  1719416473                   NaN     NaN
#
#    deleted  delivery  demo_mode  \
# 0        0         1          0
# 1        0         1          0
# 2        0         1          0
# 3        0         1          0
# 4        0         1          0
#
#                                          description  ...  variable_price  \
# 0  Burger with beyond meat patty, tomato, red oni...  ...               0
# 1  Burger with baked portobello mushroom with gar...  ...               0
# 2  Burger with Celeriach (poached in stock), toma...  ...               0
# 3  Feeling hungry? Double patty, double cheese, d...  ...               0
# 4                                                NaN  ...               0
#
#     vat  voucher                        add_on_category_ids  \
# 0  25.0        0        61551|61554|61562|61571|61575|61580
# 1  25.0        0        61551|61554|61562|61571|61575|61580
# 2  25.0        0        61551|61554|61562|61571|61575|61580
# 3  25.0        0  61566|61551|61554|61562|61571|61575|61580
# 4  25.0        0                                        NaN
#
#   printer_category_ids  standard_voucher_validity  manage_inventory  \
# 0                  NaN                        NaN                 0
# 1                  NaN                        NaN                 0
# 2                  NaN                        NaN                 0
# 3                  NaN                      365.0                 0
# 4                  NaN                        NaN                 0
#
#    all_you_can_eat  all_you_can_eat_item_ids all_you_can_eat_validity
# 0                0                       NaN                      NaN
# 1                0                       NaN                      NaN
# 2                0                       NaN                      NaN
# 3                0                       NaN                      NaN
# 4                0                       NaN                      NaN
#
# [5 rows x 36 columns]

# %%
# #5 dim_menu_item_add_ons
dim_menu_item_add_ons = pd.read_csv("Data\\dim_menu_item_add_ons.csv")
dim_menu_item_add_ons.head()
# Out:
#        id  category_id     created           title  select_as_default  status  \
# 0  296817       296816  1686064210  Bearnaisesauce                  0  Active
# 1  449630       449629  1699454781           Lille                  0  Active
# 2  449635       449629  1699454790            Stor                  0  Active
# 3  449651       449650  1699454965           Lille                  0  Active
# 4  449652       449650  1699454975            Stor                  0  Active
#
#    index  price
# 0      0    0.0
# 1      0    0.0
# 2      1   19.0
# 3      0    0.0
# 4      1    5.0
